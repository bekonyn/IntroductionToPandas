# %% [markdown]
# # Crash Course Pandas 2
# Im creating these series for people that have beginner/intermediate knowledge about pandas library.I m going to share my working notes(after tidying) to pass the info,nothing more. Certain codeblocks could get repetitive. Some info looks contradictory even though i have tried to remove most of them. Sorry for it beforehand. Also goodluck on your learning journey. This is my first kernel as well. Wish me luck. Contact me for any question, i will help you out if i can.
#
# Contents:
# * [Dataset](#1)
# * [Most provoking Talks in Online Discussion](#2)
# * [Visualizing Comment Distribution](#3)
# * [Number of Talks From Each Year](#4)
# * [Best Event in TED History](#5)
# * [Unpacking Ratings Column](#6)
# * [Total Number of Ratings Received by Each Talk](#7)
# * [Which Occupations Have the Funniest TED Talks on AVG](#8)

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
ri = pd.read_csv("../input/police.csv")
ted = pd.read_csv("../input/ted.csv")

# %% [markdown]
# <a id="1"></a>
# ## Dataset

# %%
ted.head()
# Out:
#    comments    ...        views
# 0      4553    ...     47227110
# 1       265    ...      3200520
# 2       124    ...      1636292
# 3       200    ...      1697550
# 4       593    ...     12005869
#
# [5 rows x 17 columns]

# %%
ted.shape
# Out:
# (2550, 17)

# %%
ted.dtypes
# Out:
# comments               int64
# description           object
# duration               int64
# event                 object
# film_date              int64
# languages              int64
# main_speaker          object
# name                  object
# num_speaker            int64
# published_date         int64
# ratings               object
# related_talks         object
# speaker_occupation    object
# tags                  object
# title                 object
# url                   object
# views                  int64
# dtype: object

# %%
#6 speakers with nan occupation.
ted.isna().sum()
# Out:
# comments              0
# description           0
# duration              0
# event                 0
# film_date             0
# languages             0
# main_speaker          0
# name                  0
# num_speaker           0
# published_date        0
# ratings               0
# related_talks         0
# speaker_occupation    6
# tags                  0
# title                 0
# url                   0
# views                 0
# dtype: int64

# %% [markdown]
# <a id="2"></a>
# ## Most provoking Talks in Online Discussion

# %%
ted.head()
# Out:
#    comments    ...        views
# 0      4553    ...     47227110
# 1       265    ...      3200520
# 2       124    ...      1636292
# 3       200    ...      1697550
# 4       593    ...     12005869
#
# [5 rows x 17 columns]

# %%
#you should sort the data with respect to online comments-Only the col itself.
ted.comments.sort_values(ascending=False)
# Out:
# 96      6404
# 0       4553
# 644     3356
# 201     2877
# 1787    2673
# 954     2492
# 840     2374
# 1346    2290
# 661     2272
# 677     1930
# 837     1927
# 1537    1640
# 1030    1627
# 381     1604
# 1448    1586
# 667     1545
# 694     1502
# 1453    1451
# 1450    1413
# 1940    1355
# 553     1329
# 1114    1328
# 641     1309
# 692     1234
# 1779    1234
# 730     1217
# 530     1155
# 1163    1155
# 614     1137
# 500     1094
#         ...
# 2491      11
# 2263      11
# 2428      11
# 2418      11
# 2317      11
# 2547      10
# 2465      10
# 2544      10
# 2286      10
# 2539      10
# 202        9
# 2524       9
# 2533       9
# 2319       8
# 2476       8
# 2511       8
# 2535       8
# 2549       8
# 2538       7
# 2543       7
# 2494       7
# 2313       6
# 2392       6
# 2507       6
# 2546       6
# 2407       5
# 2501       3
# 2528       3
# 2542       3
# 2534       2
# Name: comments, Length: 2550, dtype: int64

# %%
#this could work out also and also its much more better approach.Also its good idea to check event date.Bcs theyre relevant
ted.sort_values("comments",ascending=False)
# Out:
#       comments    ...        views
# 96        6404    ...      4374792
# 0         4553    ...     47227110
# 644       3356    ...      3433437
# 201       2877    ...     21190883
# 1787      2673    ...      2162764
# 954       2492    ...      1832930
# 840       2374    ...      1847256
# 1346      2290    ...     43155405
# 661       2272    ...      1838628
# 677       1930    ...     34309432
# 837       1927    ...     31168150
# 1537      1640    ...      2449736
# 1030      1627    ...      8744428
# 381       1604    ...     13155478
# 1448      1586    ...      4191678
# 667       1545    ...      2611707
# 694       1502    ...      1057238
# 1453      1451    ...      4259204
# 1450      1413    ...      3005687
# 1940      1355    ...     11443190
# 553       1329    ...     16097077
# 1114      1328    ...      2203020
# 641       1309    ...      4573252
# 692       1234    ...      7266316
# 1779      1234    ...      4548276
# 730       1217    ...      1763449
# 1163      1155    ...     17629275
# 530       1155    ...     13298341
# 614       1137    ...      7638978
# 500       1094    ...     18830983
# ...        ...    ...          ...
# 2418        11    ...       767660
# 2428        11    ...       967472
# 2491        11    ...       868290
# 2263        11    ...       443773
# 2317        11    ...       951340
# 2465        10    ...       946815
# 2544        10    ...       418368
# 2547        10    ...       375647
# 2539        10    ...       527314
# 2286        10    ...      1052018
# 2533         9    ...       248411
# 202          9    ...       620806
# 2524         9    ...       522917
# 2535         8    ...       707788
# 2549         8    ...       391721
# 2319         8    ...       738590
# 2511         8    ...       552732
# 2476         8    ...       815611
# 2538         7    ...       621431
# 2543         7    ...       534824
# 2494         7    ...      1005506
# 2313         6    ...       820295
# 2392         6    ...       760537
# 2507         6    ...       182975
# 2546         6    ...       417470
# 2407         5    ...       640734
# 2528         3    ...       539207
# 2542         3    ...       542088
# 2501         3    ...       839040
# 2534         2    ...       646174
#
# [2550 rows x 17 columns]

# %%
#but how can we use event date? We can use views.its much more clear approach.
ted["comments_per_view"]=ted.comments/ted.views

# %%
ted.sort_values("comments_per_view",ascending=False)
# Out:
#       comments        ...        comments_per_view
# 744        649        ...                 0.002220
# 803        834        ...                 0.001534
# 96        6404        ...                 0.001464
# 694       1502        ...                 0.001421
# 954       2492        ...                 0.001360
# 840       2374        ...                 0.001285
# 876        555        ...                 0.001264
# 1787      2673        ...                 0.001236
# 661       2272        ...                 0.001236
# 561        595        ...                 0.001235
# 1250       208        ...                 0.001193
# 443        846        ...                 0.001091
# 732        804        ...                 0.000981
# 1148       775        ...                 0.000978
# 644       3356        ...                 0.000977
# 829        831        ...                 0.000976
# 95         588        ...                 0.000954
# 1198       175        ...                 0.000939
# 969        471        ...                 0.000896
# 786        954        ...                 0.000887
# 1060       254        ...                 0.000884
# 1061       118        ...                 0.000850
# 1180       514        ...                 0.000838
# 1111       325        ...                 0.000832
# 955        383        ...                 0.000830
# 655        368        ...                 0.000819
# 791        225        ...                 0.000807
# 580        307        ...                 0.000780
# 851        356        ...                 0.000771
# 1106       211        ...                 0.000761
# ...        ...        ...                      ...
# 2302        24        ...                 0.000013
# 2173        23        ...                 0.000013
# 2543         7        ...                 0.000013
# 2491        11        ...                 0.000013
# 2504        18        ...                 0.000013
# 2101        35        ...                 0.000012
# 2446        13        ...                 0.000012
# 2052        12        ...                 0.000012
# 2215        36        ...                 0.000012
# 2486        12        ...                 0.000012
# 2317        11        ...                 0.000012
# 2428        11        ...                 0.000011
# 2535         8        ...                 0.000011
# 2538         7        ...                 0.000011
# 2319         8        ...                 0.000011
# 2465        10        ...                 0.000011
# 2125        19        ...                 0.000010
# 2146        17        ...                 0.000010
# 2476         8        ...                 0.000010
# 2286        10        ...                 0.000010
# 2273        46        ...                 0.000008
# 2392         6        ...                 0.000008
# 2407         5        ...                 0.000008
# 2114       150        ...                 0.000007
# 2313         6        ...                 0.000007
# 2494         7        ...                 0.000007
# 2528         3        ...                 0.000006
# 2542         3        ...                 0.000006
# 2501         3        ...                 0.000004
# 2534         2        ...                 0.000003
#
# [2550 rows x 18 columns]

# %%
#another approach-same mentality
ted["views_per_comment"]=ted.views/ted.comments

# %%
ted.sort_values("views_per_comment")
# Out:
#       comments        ...        views_per_comment
# 744        649        ...               450.531587
# 803        834        ...               651.739808
# 96        6404        ...               683.134291
# 694       1502        ...               703.886818
# 954       2492        ...               735.525682
# 840       2374        ...               778.119629
# 876        555        ...               791.315315
# 1787      2673        ...               809.114852
# 661       2272        ...               809.255282
# 561        595        ...               809.805042
# 1250       208        ...               838.105769
# 443        846        ...               916.583924
# 732        804        ...              1019.105721
# 1148       775        ...              1022.940645
# 644       3356        ...              1023.074195
# 829        831        ...              1025.104693
# 95         588        ...              1048.273810
# 1198       175        ...              1064.617143
# 969        471        ...              1115.596603
# 786        954        ...              1127.039832
# 1060       254        ...              1131.559055
# 1061       118        ...              1176.372881
# 1180       514        ...              1193.922179
# 1111       325        ...              1201.215385
# 955        383        ...              1204.652742
# 655        368        ...              1220.546196
# 791        225        ...              1238.542222
# 580        307        ...              1281.625407
# 851        356        ...              1297.786517
# 1106       211        ...              1314.341232
# ...        ...        ...                      ...
# 2302        24        ...             75465.750000
# 2173        23        ...             75825.521739
# 2543         7        ...             76403.428571
# 2491        11        ...             78935.454545
# 2504        18        ...             79817.444444
# 2101        35        ...             81504.685714
# 2446        13        ...             83026.846154
# 2052        12        ...             83711.583333
# 2215        36        ...             83796.277778
# 2486        12        ...             85976.333333
# 2317        11        ...             86485.454545
# 2428        11        ...             87952.000000
# 2535         8        ...             88473.500000
# 2538         7        ...             88775.857143
# 2319         8        ...             92323.750000
# 2465        10        ...             94681.500000
# 2125        19        ...             97548.631579
# 2146        17        ...             98668.823529
# 2476         8        ...            101951.375000
# 2286        10        ...            105201.800000
# 2273        46        ...            124170.282609
# 2392         6        ...            126756.166667
# 2407         5        ...            128146.800000
# 2114       150        ...            136506.480000
# 2313         6        ...            136715.833333
# 2494         7        ...            143643.714286
# 2528         3        ...            179735.666667
# 2542         3        ...            180696.000000
# 2501         3        ...            279680.000000
# 2534         2        ...            323087.000000
#
# [2550 rows x 19 columns]

# %% [markdown]
# <a id="3"></a>
# ## Visualizing Comment Distribution

# %%
ted.shape
# Out:
# (2550, 19)

# %%
#x is index,y is # of comments
ted.comments.plot()
#kind->line,bar,barh,hist,box,kde,density,area,pie.default is line which is not very informative

# %%
#most of the comments (nearly all of them) has btw 0 to ~600 comments.but changing binwidth could be more helpful.
ted.comments.plot(kind="hist")

# %%
#via using seaborn we could get much more good looking visuals however this is pandas workout so...
ted[ted.comments<=1000].comments.plot(kind="hist")
#this could help out.

# %%
#using loc
ted.loc[ted.comments<=1000,"comments"].plot(kind="hist")
#loc is very good,u can select single col,multi col,list of cols,range of cols.

# %%
#increasing bin size makes our plot more informative.50-100 comment range is the real deal.
ted.loc[ted.comments<=1000,"comments"].plot(kind="hist",bins=20)
#choose

# %%
#choose your plot type carefully
#histogram for distribution
#barplot for comparing categories
#lineplot good for timeseries(change w time)
#scatterplot good for comparing multiple variable (comparing 2 variables)
#check pandas visualization page for more info
#https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html
#pandas plots are more exploratory data analysis friendly however matplotlib is much more customizable

# %% [markdown]
# <a id="4"></a>
# ## Number of Talks From Each Year

# %%
ted.head()
# Out:
#    comments        ...        views_per_comment
# 0      4553        ...             10372.745443
# 1       265        ...             12077.433962
# 2       124        ...             13195.903226
# 3       200        ...              8487.750000
# 4       593        ...             20245.984823
#
# [5 rows x 19 columns]

# %%
#as u can see data doesnt always have "ted2014" format. so ted.event.str.split(2,6) doesnt work.
ted.event.value_counts()
# Out:
# TED2014                        84
# TED2009                        83
# TED2013                        77
# TED2016                        77
# TED2015                        75
# TED2011                        70
# TEDGlobal 2012                 70
# TED2007                        68
# TED2010                        68
# TEDGlobal 2011                 68
# TED2017                        67
# TEDGlobal 2013                 66
# TEDGlobal 2009                 65
# TED2012                        65
# TED2008                        57
# TEDGlobal 2010                 55
# TEDGlobal 2014                 51
# TED2006                        45
# TED2005                        37
# TEDIndia 2009                  35
# TEDWomen 2010                  34
# TEDSummit                      34
# TED2003                        34
# TED2004                        31
# TED2002                        28
# TEDWomen 2015                  28
# TEDGlobal 2007                 27
# TEDGlobal 2005                 26
# TEDWomen 2016                  25
# TEDxBeaconStreet               22
#                                ..
# TEDxEQChCh                      1
# TEDxDesMoines                   1
# TEDxBoston 2010                 1
# TEDxColumbusWomen               1
# TEDxZurich                      1
# TEDxGroningen                   1
# Global Witness HQ               1
# NextGen:Charity                 1
# TEDxArendal                     1
# World Science Festival          1
# TEDxGatewayWomen                1
# TEDxSantaCruz                   1
# TEDxSBU                         1
# TEDxSussexUniversity            1
# TED-Ed Weekend                  1
# Justice with Michael Sandel     1
# TEDxPuget Sound                 1
# TEDxZurich 2013                 1
# TEDxNorthwesternU               1
# TED@Bangalore                   1
# TEDxCrenshaw                    1
# TEDxSonomaCounty                1
# TED Prize Wish                  1
# LIFT 2007                       1
# TEDxMIA                         1
# TEDxHogeschoolUtrecht           1
# TEDxAsheville                   1
# TEDxDU 2011                     1
# TEDxFrankfurt                   1
# TEDxEastEnd                     1
# Name: event, Length: 355, dtype: int64

# %%
#value_counts() do the job however just for sake of using dif argument lets use sample
ted.event.sample(10)
# Out:
# 342                  TED2006
# 1066          TEDGlobal 2011
# 1408                 TED2012
# 1549                 TED2013
# 874     TEDSalon London 2010
# 1228                 TED2012
# 151                  TED2007
# 215                  TED2008
# 2379         TEDxMidAtlantic
# 1409         TEDSalon NY2012
# Name: event, dtype: object

# %%
#so event col doesnt help us lets look another field, film_date which is created by unix timestamps
ted.film_date.head()
#believe it or not pd.to_datetime very smart tool...
# Out:
# 0    1140825600
# 1    1140825600
# 2    1140739200
# 3    1140912000
# 4    1140566400
# Name: film_date, dtype: int64

# %%
#its somewhat achievement but not totally.
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_datetime.html
#search the bottom of the manual/documentation to see sth about unix timestamps.
pd.to_datetime(ted.film_date).head()
# Out:
# 0   1970-01-01 00:00:01.140825600
# 1   1970-01-01 00:00:01.140825600
# 2   1970-01-01 00:00:01.140739200
# 3   1970-01-01 00:00:01.140912000
# 4   1970-01-01 00:00:01.140566400
# Name: film_date, dtype: datetime64[ns]

# %%
#this is much better.
pd.to_datetime(ted.film_date,unit="s").head()
# Out:
# 0   2006-02-25
# 1   2006-02-25
# 2   2006-02-24
# 3   2006-02-26
# 4   2006-02-22
# Name: film_date, dtype: datetime64[ns]

# %%
#lets store it
ted["film_datetime"]=pd.to_datetime(ted.film_date,unit="s")

# %%
#lets check it out.but not with head() this time.we should use other data control tools from time to time
ted.loc[:,["event","film_datetime"]].sample(10)
# Out:
#                      event film_datetime
# 2527          TEDxStanford    2017-04-23
# 93                 TED2003    2003-02-02
# 2212               TED2016    2016-02-18
# 2172      TEDxBeaconStreet    2015-11-14
# 2341         TEDWomen 2016    2016-10-27
# 715   TEDSalon London 2010    2010-04-25
# 518         TEDGlobal 2009    2009-07-22
# 757          TEDIndia 2009    2009-11-04
# 1637               TED2013    2013-02-25
# 2542        TEDGlobal 2017    2017-08-27

# %%
#OR
ted[["event","film_datetime"]].sample(10)
# Out:
#                event film_datetime
# 78           TED2003    2003-02-27
# 1777    TEDxColumbus    2013-10-10
# 1242         TED2012    2012-02-29
# 950          TED2011    2011-03-02
# 2274  TED Talks Live    2015-11-02
# 1068        TEDxTeen    2011-04-02
# 888          TED2011    2011-03-01
# 8            TED2006    2006-02-02
# 448          TED2009    2009-02-04
# 2328  TED Talks Live    2015-11-02

# %%
#checking data types is useful.our film_datetime is datetime dtype.
ted.dtypes
# Out:
# comments                       int64
# description                   object
# duration                       int64
# event                         object
# film_date                      int64
# languages                      int64
# main_speaker                  object
# name                          object
# num_speaker                    int64
# published_date                 int64
# ratings                       object
# related_talks                 object
# speaker_occupation            object
# tags                          object
# title                         object
# url                           object
# views                          int64
# comments_per_view            float64
# views_per_comment            float64
# film_datetime         datetime64[ns]
# dtype: object

# %%
#datetime methods/attributes have same logic like string(str) methods(attributes) data.col.str.method()
ted.film_datetime.dt.year.head()
# Out:
# 0    2006
# 1    2006
# 2    2006
# 3    2006
# 4    2006
# Name: film_datetime, dtype: int64

# %%
#ted.film_datetime.dt.year.value_counts().index -> 2013,2011 etc are all indexex/indices.check their order...
ted.film_datetime.dt.year.value_counts()
# Out:
# 2013    270
# 2011    270
# 2010    267
# 2012    267
# 2016    246
# 2015    239
# 2014    237
# 2009    232
# 2007    114
# 2017     98
# 2008     84
# 2005     66
# 2006     50
# 2003     33
# 2004     33
# 2002     27
# 1998      6
# 2001      5
# 1983      1
# 1991      1
# 1994      1
# 1990      1
# 1984      1
# 1972      1
# Name: film_datetime, dtype: int64

# %%
#plotting time.lets try couple.
ted.film_datetime.dt.year.value_counts().plot(kind="bar")
#not the one we are looking for,barplots are good for catg data.and you cant consider years as categories for this case.

# %%
#x=no of talks y=no of occurence/freq. however this doesnt help us either.
ted.film_datetime.dt.year.value_counts().plot(kind="hist")

# %%
#this could help us,however there is a problem.its sort index issue.
ted.film_datetime.dt.year.value_counts().plot(kind="line")

# %%
#looks like there is a sharp decline in tedtalk talk counts.lets investigate further.
ted.film_datetime.dt.year.value_counts().sort_index().plot(kind="line")

# %%
#latest talk datetime.so we cant be sure for present time(2019)
ted.film_datetime.max()
# Out:
# Timestamp('2017-08-27 00:00:00')

# %%
#tip:read the documentation if u have a clue about how to achieve sth but you dont get a proper result completely.
#always remember to_datetime/datetime when you are working w date.

# %% [markdown]
# <a id="5"></a>
# ## Best Event in TED History

# %%
ted
# Out:
#       comments      ...      film_datetime
# 0         4553      ...         2006-02-25
# 1          265      ...         2006-02-25
# 2          124      ...         2006-02-24
# 3          200      ...         2006-02-26
# 4          593      ...         2006-02-22
# 5          672      ...         2006-02-02
# 6          919      ...         2006-02-24
# 7           46      ...         2006-02-23
# 8          852      ...         2006-02-02
# 9          900      ...         2006-02-25
# 10          79      ...         2006-02-26
# 11          55      ...         2006-02-26
# 12          71      ...         2006-02-23
# 13         242      ...         2006-02-06
# 14          99      ...         2006-02-23
# 15         325      ...         2006-02-23
# 16         305      ...         2004-02-26
# 17          88      ...         2006-02-24
# 18         163      ...         2005-02-25
# 19          84      ...         2005-07-14
# 20         108      ...         2006-02-23
# 21         185      ...         2004-02-24
# 22          50      ...         2006-02-23
# 23         556      ...         2006-02-24
# 24         117      ...         2004-02-04
# 25         184      ...         2005-07-14
# 26         507      ...         2005-07-07
# 27          95      ...         2004-02-27
# 28         355      ...         2004-02-26
# 29         970      ...         2004-02-02
# ...        ...      ...                ...
# 2520        81      ...         2017-04-24
# 2521        13      ...         2016-04-24
# 2522        12      ...         2017-04-24
# 2523        20      ...         2016-10-08
# 2524         9      ...         2017-04-24
# 2525        18      ...         2016-05-24
# 2526        39      ...         2017-04-24
# 2527        17      ...         2017-04-23
# 2528         3      ...         2016-06-08
# 2529        45      ...         2015-04-24
# 2530        12      ...         2017-04-24
# 2531        18      ...         2016-06-18
# 2532        25      ...         2017-04-24
# 2533         9      ...         2017-04-24
# 2534         2      ...         2017-04-07
# 2535         8      ...         2017-08-27
# 2536        21      ...         2017-07-08
# 2537        39      ...         2017-04-24
# 2538         7      ...         2016-11-11
# 2539        10      ...         2017-08-27
# 2540        33      ...         2017-07-20
# 2541        12      ...         2017-02-19
# 2542         3      ...         2017-08-27
# 2543         7      ...         2017-04-24
# 2544        10      ...         2017-08-27
# 2545        17      ...         2017-06-06
# 2546         6      ...         2017-04-24
# 2547        10      ...         2017-04-24
# 2548        32      ...         2017-07-08
# 2549         8      ...         2017-04-24
#
# [2550 rows x 20 columns]

# %%
#count the no of talks? 1. parameter to look up to.
ted.event.value_counts().head()
# Out:
# TED2014    84
# TED2009    83
# TED2013    77
# TED2016    77
# TED2015    75
# Name: event, dtype: int64

# %%
#here is a long series of explanation..starts from here
#this data has 896 values.groupby uses max 5 values from that dset for each group.therefore dset w 2550 rows becomes 896
ted.groupby("event").event.head()
# Out:
# 0                       TED2006
# 1                       TED2006
# 2                       TED2006
# 3                       TED2006
# 4                       TED2006
# 16                      TED2004
# 18                      TED2005
# 19               TEDGlobal 2005
# 21                      TED2004
# 24                      TED2004
# 25               TEDGlobal 2005
# 26               TEDGlobal 2005
# 27                      TED2004
# 28                      TED2004
# 30               TEDGlobal 2005
# 31                      TED2005
# 32               TEDGlobal 2005
# 38                      TED2005
# 39                      TED2005
# 40                      TED2005
# 48                TEDSalon 2006
# 52                      TED2003
# 56                TEDSalon 2006
# 63                      TED2007
# 64                      TED2007
# 65                      TED2007
# 66                      TED2002
# 67                      TED2003
# 70                      TED2002
# 71                      TED2003
#                  ...
# 2435             TEDxSanQuentin
# 2436      TEDLagos Ideas Search
# 2437           TEDxVirginiaTech
# 2438                    TED2017
# 2439                    TED2017
# 2440                    TED2017
# 2441                    TED2017
# 2442                  TEDxSkoll
# 2443                    TED2017
# 2444      TEDLagos Ideas Search
# 2454         TEDxManhattanBeach
# 2457    TEDNairobi Ideas Search
# 2461        TEDxFulbrightDublin
# 2463              TED Residency
# 2474            TEDxOrcasIsland
# 2492              TED Residency
# 2506               TEDxMileHigh
# 2514     TEDxPennsylvaniaAvenue
# 2523               TEDxCrenshaw
# 2528                TEDxHamburg
# 2531                  TEDxGhent
# 2534                  TEDxSkoll
# 2535             TEDGlobal 2017
# 2536               TEDxMileHigh
# 2538                 TEDxZurich
# 2540                    TED@UPS
# 2541             TEDxManchester
# 2542             TEDGlobal 2017
# 2544             TEDGlobal 2017
# 2548               TEDxMileHigh
# Name: event, Length: 896, dtype: object

# %%
#and here is their views col.
ted.groupby("event").views.head()
# Out:
# 0       47227110
# 1        3200520
# 2        1636292
# 3        1697550
# 4       12005869
# 16       1628912
# 18       1074081
# 19       1106561
# 21       6141440
# 24       1131864
# 25       1096862
# 26       2885999
# 27       2863214
# 28       7023562
# 30      10000702
# 31       1030267
# 32       3277740
# 38        745231
# 39        718649
# 40        975107
# 48       1813665
# 52       2532851
# 56        684519
# 63        849859
# 64       1335732
# 65       1262674
# 66       1663001
# 67       5570544
# 70        680134
# 71        690928
#           ...
# 2435     2198889
# 2436     1036236
# 2437      872015
# 2438     2679881
# 2439     1426132
# 2440     2178534
# 2441     5666038
# 2442      918385
# 2443     1132913
# 2444     1460852
# 2454     1219828
# 2457      696847
# 2461     1052652
# 2463      957803
# 2474      977590
# 2492     1026708
# 2506     1319327
# 2514      748485
# 2523      744793
# 2528      539207
# 2531      665328
# 2534      646174
# 2535      707788
# 2536      566101
# 2538      621431
# 2540      613915
# 2541      656791
# 2542      542088
# 2544      418368
# 2548      419309
# Name: views, Length: 896, dtype: int64

# %%
#here is the whole dataframe.
ted.groupby("event").head()
# Out:
#       comments      ...      film_datetime
# 0         4553      ...         2006-02-25
# 1          265      ...         2006-02-25
# 2          124      ...         2006-02-24
# 3          200      ...         2006-02-26
# 4          593      ...         2006-02-22
# 16         305      ...         2004-02-26
# 18         163      ...         2005-02-25
# 19          84      ...         2005-07-14
# 21         185      ...         2004-02-24
# 24         117      ...         2004-02-04
# 25         184      ...         2005-07-14
# 26         507      ...         2005-07-07
# 27          95      ...         2004-02-27
# 28         355      ...         2004-02-26
# 30         991      ...         2005-07-15
# 31         213      ...         2005-02-26
# 32         612      ...         2005-07-14
# 38          57      ...         2005-02-24
# 39         112      ...         2005-02-24
# 40          58      ...         2005-02-17
# 48          95      ...         2006-11-30
# 52         371      ...         2003-02-03
# 56          47      ...         2006-11-30
# 63          97      ...         2007-03-08
# 64          89      ...         2007-03-08
# 65         107      ...         2007-03-08
# 66         161      ...         2002-03-01
# 67         220      ...         2003-02-27
# 70         130      ...         2002-02-02
# 71          49      ...         2003-02-02
# ...        ...      ...                ...
# 2435        67      ...         2016-01-22
# 2436        53      ...         2017-02-11
# 2437        23      ...         2016-11-10
# 2438       235      ...         2017-04-25
# 2439        22      ...         2017-04-24
# 2440        51      ...         2017-04-24
# 2441       250      ...         2017-04-24
# 2442        92      ...         2017-04-07
# 2443        80      ...         2017-04-24
# 2444        35      ...         2017-02-11
# 2454        64      ...         2016-11-05
# 2457        12      ...         2017-02-08
# 2461        33      ...         2016-02-06
# 2463        34      ...         2016-12-13
# 2474        41      ...         2016-03-05
# 2492        15      ...         2016-12-13
# 2506        36      ...         2017-07-08
# 2514        14      ...         2017-02-09
# 2523        20      ...         2016-10-08
# 2528         3      ...         2016-06-08
# 2531        18      ...         2016-06-18
# 2534         2      ...         2017-04-07
# 2535         8      ...         2017-08-27
# 2536        21      ...         2017-07-08
# 2538         7      ...         2016-11-11
# 2540        33      ...         2017-07-20
# 2541        12      ...         2017-02-19
# 2542         3      ...         2017-08-27
# 2544        10      ...         2017-08-27
# 2548        32      ...         2017-07-08
#
# [896 rows x 20 columns]

# %%
#lets check out multiple aggregate functions at once.dont get confused not all ted talks has "TED" in their event names.
ted.groupby("event").views.mean().sort_values(ascending=False)
#why use mean->because some talks occurred on same place.
# Out:
# event
# TEDxPuget Sound                         3.430943e+07
# TEDxHouston                             1.614025e+07
# TEDxBloomington                         9.484260e+06
# TEDxCreativeCoast                       8.444981e+06
# TEDxNorrkoping                          6.569493e+06
# TEDxUW                                  5.917201e+06
# TEDxLinnaeusUniversity                  4.984884e+06
# TEDxGoldenGatePark 2012                 4.811180e+06
# TEDxCHUV                                4.682458e+06
# Stanford University                     4.658636e+06
# TEDxAmericanRiviera                     4.384497e+06
# TED Talks Education                     4.375104e+06
# TEDxBinghamtonUniversity                4.340117e+06
# TEDxMet                                 4.207626e+06
# TEDxParis 2012                          3.840850e+06
# TEDxSF                                  3.658158e+06
# TEDxMtHood                              3.464767e+06
# TEDGlobal>Geneva                        3.385408e+06
# TEDxIndianapolis                        3.361105e+06
# World Science Festival                  3.302312e+06
# TED2006                                 3.274345e+06
# TEDxConcordiaUPortland                  3.270359e+06
# TEDxManhattanBeach                      3.251704e+06
# TEDxKyoto                               3.198337e+06
# TEDxChapmanU                            3.098476e+06
# TEDxBend                                2.981683e+06
# TEDxKids@Ambleside                      2.954036e+06
# TEDxJaffa 2013                          2.931366e+06
# TEDSalon NY2013                         2.861639e+06
# TEDxEQChCh                              2.829484e+06
#                                             ...
# TEDxDU 2011                             3.693630e+05
# TEDxUCL                                 3.533500e+05
# TEDxMIA                                 3.489920e+05
# TEDxSanMigueldeAllende                  3.203960e+05
# Royal Institution                       3.184230e+05
# TED Senior Fellows at TEDGlobal 2010    3.171270e+05
# Business Innovation Factory             3.040860e+05
# TEDxABQ                                 2.987760e+05
# NextGen:Charity                         2.936260e+05
# New York State Senate                   2.923950e+05
# TEDxO'Porto                             2.912510e+05
# TEDxSantaCruz                           2.874160e+05
# TEDxPhoenix                             2.846855e+05
# TEDSalon 2009 Compassion                2.818163e+05
# Fort Worth City Council                 2.786720e+05
# TEDYouth 2012                           2.749860e+05
# University of California                2.618315e+05
# Chautauqua Institution                  2.608687e+05
# Handheld Learning                       2.513130e+05
# TEDxPittsburgh                          2.081150e+05
# TEDxDirigo                              1.915550e+05
# Michael Howard Studios                  1.769950e+05
# TEDxSussexUniversity                    1.743260e+05
# TEDxMonterey                            1.668350e+05
# TEDxObserver                            1.625270e+05
# TEDxNASA@SiliconValley                  1.558950e+05
# AORN Congress                           1.498180e+05
# TEDxWaterloo                            1.388120e+05
# TEDxIslay                               1.202740e+05
# The Do Lectures                         1.123210e+05
# Name: views, Length: 355, dtype: float64

# %%
#ted.groupby("event").views.count().sort_values(ascending=False) is unnecessary to look bcs
#ted.event.value_counts() does the same job.
#Now lets try to put count and mean in same table.

# %%
ted.groupby("event").views.agg(["count","mean"]).sort_values(by="mean",ascending=False)
# Out:
#                                       count          mean
# event
# TEDxPuget Sound                           1  3.430943e+07
# TEDxHouston                               2  1.614025e+07
# TEDxBloomington                           2  9.484260e+06
# TEDxCreativeCoast                         1  8.444981e+06
# TEDxNorrkoping                            1  6.569493e+06
# TEDxUW                                    1  5.917201e+06
# TEDxLinnaeusUniversity                    1  4.984884e+06
# TEDxGoldenGatePark 2012                   1  4.811180e+06
# TEDxCHUV                                  1  4.682458e+06
# Stanford University                       2  4.658636e+06
# TEDxAmericanRiviera                       1  4.384497e+06
# TED Talks Education                       8  4.375104e+06
# TEDxBinghamtonUniversity                  1  4.340117e+06
# TEDxMet                                   2  4.207626e+06
# TEDxParis 2012                            1  3.840850e+06
# TEDxSF                                    1  3.658158e+06
# TEDxMtHood                                1  3.464767e+06
# TEDGlobal>Geneva                         11  3.385408e+06
# TEDxIndianapolis                          1  3.361105e+06
# World Science Festival                    1  3.302312e+06
# TED2006                                  45  3.274345e+06
# TEDxConcordiaUPortland                    1  3.270359e+06
# TEDxManhattanBeach                        3  3.251704e+06
# TEDxKyoto                                 2  3.198337e+06
# TEDxChapmanU                              1  3.098476e+06
# TEDxBend                                  2  2.981683e+06
# TEDxKids@Ambleside                        1  2.954036e+06
# TEDxJaffa 2013                            1  2.931366e+06
# TEDSalon NY2013                          11  2.861639e+06
# TEDxEQChCh                                1  2.829484e+06
# ...                                     ...           ...
# TEDxDU 2011                               1  3.693630e+05
# TEDxUCL                                   1  3.533500e+05
# TEDxMIA                                   1  3.489920e+05
# TEDxSanMigueldeAllende                    2  3.203960e+05
# Royal Institution                         1  3.184230e+05
# TED Senior Fellows at TEDGlobal 2010      1  3.171270e+05
# Business Innovation Factory               3  3.040860e+05
# TEDxABQ                                   1  2.987760e+05
# NextGen:Charity                           1  2.936260e+05
# New York State Senate                     1  2.923950e+05
# TEDxO'Porto                               1  2.912510e+05
# TEDxSantaCruz                             1  2.874160e+05
# TEDxPhoenix                               4  2.846855e+05
# TEDSalon 2009 Compassion                  3  2.818163e+05
# Fort Worth City Council                   1  2.786720e+05
# TEDYouth 2012                             1  2.749860e+05
# University of California                  2  2.618315e+05
# Chautauqua Institution                    3  2.608687e+05
# Handheld Learning                         1  2.513130e+05
# TEDxPittsburgh                            1  2.081150e+05
# TEDxDirigo                                1  1.915550e+05
# Michael Howard Studios                    1  1.769950e+05
# TEDxSussexUniversity                      1  1.743260e+05
# TEDxMonterey                              1  1.668350e+05
# TEDxObserver                              2  1.625270e+05
# TEDxNASA@SiliconValley                    1  1.558950e+05
# AORN Congress                             1  1.498180e+05
# TEDxWaterloo                              1  1.388120e+05
# TEDxIslay                                 1  1.202740e+05
# The Do Lectures                           1  1.123210e+05
#
# [355 rows x 2 columns]

# %%
#lets add sum too.Now we can see the total no of views
ted.groupby("event").views.agg(["count","mean","sum"]).sort_values(by="sum",ascending=False)
#there are many criterias to measure performance.1 time mass hit talk vs many talks-good amount of views...
# Out:
#                                       count          mean        sum
# event
# TED2013                                  77  2.302700e+06  177307937
# TED2014                                  84  2.072874e+06  174121423
# TEDGlobal 2013                           66  2.584163e+06  170554736
# TED2015                                  75  2.011017e+06  150826305
# TED2006                                  45  3.274345e+06  147345533
# TED2009                                  83  1.754896e+06  145656385
# TEDGlobal 2012                           70  2.072436e+06  145070549
# TED2012                                  65  2.223040e+06  144497608
# TED2016                                  77  1.812622e+06  139571905
# TED2011                                  70  1.967864e+06  137750504
# TED2010                                  68  1.798071e+06  122268845
# TEDGlobal 2011                           68  1.717761e+06  116807745
# TED2008                                  57  2.038647e+06  116202871
# TEDGlobal 2009                           65  1.679021e+06  109136352
# TED2007                                  68  1.511131e+06  102756885
# TED2004                                  31  2.693644e+06   83502957
# TED2017                                  67  1.188258e+06   79613259
# TEDGlobal 2010                           55  1.338910e+06   73640042
# TEDGlobal 2014                           51  1.316167e+06   67124493
# TED2005                                  37  1.786187e+06   66088906
# TEDSummit                                34  1.529963e+06   52018727
# TEDxBeaconStreet                         22  2.207495e+06   48564891
# TEDIndia 2009                            35  1.359085e+06   47567971
# TEDWomen 2010                            34  1.298086e+06   44134937
# TEDGlobal 2005                           26  1.639063e+06   42615627
# TEDWomen 2015                            28  1.449902e+06   40597242
# TEDxMidAtlantic                          17  2.305604e+06   39195275
# TED2003                                  34  1.111202e+06   37780871
# TEDGlobal>Geneva                         11  3.385408e+06   37239487
# TED Talks Education                       8  4.375104e+06   35000830
# ...                                     ...           ...        ...
# TED Prize Wish                            1  4.212120e+05     421212
# TEDxAsheville                             1  4.186510e+05     418651
# Skoll World Forum 2007                    1  4.182340e+05     418234
# TEDxMiamiUniversity                       1  4.074190e+05     407419
# Eric Whitacre's Virtual Choir             1  3.992800e+05     399280
# Justice with Michael Sandel               1  3.934590e+05     393459
# TEDxDU 2011                               1  3.693630e+05     369363
# TEDxUCL                                   1  3.533500e+05     353350
# TEDxMIA                                   1  3.489920e+05     348992
# TEDxObserver                              2  1.625270e+05     325054
# Royal Institution                         1  3.184230e+05     318423
# TED Senior Fellows at TEDGlobal 2010      1  3.171270e+05     317127
# TEDxABQ                                   1  2.987760e+05     298776
# NextGen:Charity                           1  2.936260e+05     293626
# New York State Senate                     1  2.923950e+05     292395
# TEDxO'Porto                               1  2.912510e+05     291251
# TEDxSantaCruz                             1  2.874160e+05     287416
# Fort Worth City Council                   1  2.786720e+05     278672
# TEDYouth 2012                             1  2.749860e+05     274986
# Handheld Learning                         1  2.513130e+05     251313
# TEDxPittsburgh                            1  2.081150e+05     208115
# TEDxDirigo                                1  1.915550e+05     191555
# Michael Howard Studios                    1  1.769950e+05     176995
# TEDxSussexUniversity                      1  1.743260e+05     174326
# TEDxMonterey                              1  1.668350e+05     166835
# TEDxNASA@SiliconValley                    1  1.558950e+05     155895
# AORN Congress                             1  1.498180e+05     149818
# TEDxWaterloo                              1  1.388120e+05     138812
# TEDxIslay                                 1  1.202740e+05     120274
# The Do Lectures                           1  1.123210e+05     112321
#
# [355 rows x 3 columns]

# %% [markdown]
# <a id="6"></a>
# ## Unpacking Ratings Column

# %%
ted.head()
# Out:
#    comments      ...      film_datetime
# 0      4553      ...         2006-02-25
# 1       265      ...         2006-02-25
# 2       124      ...         2006-02-24
# 3       200      ...         2006-02-26
# 4       593      ...         2006-02-22
#
# [5 rows x 20 columns]

# %%
#ratings=there used to be a way on ted website to tag talks for site visiters.
ted.ratings.head()
# Out:
# 0    [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1    [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2    [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3    [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4    [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# Name: ratings, dtype: object

# %%
#to get first row.
#ted.ratings[0]
ted.loc[0,"ratings"]
# Out:
# "[{'id': 7, 'name': 'Funny', 'count': 19645}, {'id': 1, 'name': 'Beautiful', 'count': 4573}, {'id': 9, 'name': 'Ingenious', 'count': 6073}, {'id': 3, 'name': 'Courageous', 'count': 3253}, {'id': 11, 'name': 'Longwinded', 'count': 387}, {'id': 2, 'name': 'Confusing', 'count': 242}, {'id': 8, 'name': 'Informative', 'count': 7346}, {'id': 22, 'name': 'Fascinating', 'count': 10581}, {'id': 21, 'name': 'Unconvincing', 'count': 300}, {'id': 24, 'name': 'Persuasive', 'count': 10704}, {'id': 23, 'name': 'Jaw-dropping', 'count': 4439}, {'id': 25, 'name': 'OK', 'count': 1174}, {'id': 26, 'name': 'Obnoxious', 'count': 209}, {'id': 10, 'name': 'Inspiring', 'count': 24924}]"

# %%
#ratings col data is "stringified list of dictionaries" its not a list of dictionaries,its a string.
type(ted.ratings[0])
#now how can we unpack this complex data?
# Out:
# str

# %%
import ast
#abstract syntax tree.

# %%
#if i enter string that looks like a list, literal_eval returns a list.
ast.literal_eval("[1,2,3]")
# Out:
# [1, 2, 3]

# %%
type(ast.literal_eval("[1,2,3]"))
#stringified integer,stringified list.. it can deal with it.
# Out:
# list

# %%
#here is our list.its a list of dictionaries.now we need to apply this to all col.
ast.literal_eval(ted.ratings[0])
# Out:
# [{'id': 7, 'name': 'Funny', 'count': 19645},
#  {'id': 1, 'name': 'Beautiful', 'count': 4573},
#  {'id': 9, 'name': 'Ingenious', 'count': 6073},
#  {'id': 3, 'name': 'Courageous', 'count': 3253},
#  {'id': 11, 'name': 'Longwinded', 'count': 387},
#  {'id': 2, 'name': 'Confusing', 'count': 242},
#  {'id': 8, 'name': 'Informative', 'count': 7346},
#  {'id': 22, 'name': 'Fascinating', 'count': 10581},
#  {'id': 21, 'name': 'Unconvincing', 'count': 300},
#  {'id': 24, 'name': 'Persuasive', 'count': 10704},
#  {'id': 23, 'name': 'Jaw-dropping', 'count': 4439},
#  {'id': 25, 'name': 'OK', 'count': 1174},
#  {'id': 26, 'name': 'Obnoxious', 'count': 209},
#  {'id': 10, 'name': 'Inspiring', 'count': 24924}]

# %%
#first solve it via f()
def str_to_list(ratings_str):
    return ast.literal_eval(ratings_str)

# %%
#that result looks good.str_to_list(ratings) doesnt needed.bcs we are looking to the ratings col.python gets what we are
#trying to accomplish.
ted.ratings.apply(str_to_list).head()
# Out:
# 0    [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1    [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2    [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3    [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4    [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# Name: ratings, dtype: object

# %%
#however no function is necessary.
ted.ratings.apply(ast.literal_eval).head()
# Out:
# 0    [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1    [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2    [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3    [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4    [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# Name: ratings, dtype: object

# %%
#lets do lambda f() version to see what is lambda f() does
ted.ratings.apply(lambda x: ast.literal_eval(x)).head()
# Out:
# 0    [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1    [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2    [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3    [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4    [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# Name: ratings, dtype: object

# %%
#lets save it as actual col
ted["rating_list"]=ted.ratings.apply(lambda x: ast.literal_eval(x))

# %%
#rating_list considered as object.its not a string columns!,its a column that contains list.
ted.dtypes
# Out:
# comments                       int64
# description                   object
# duration                       int64
# event                         object
# film_date                      int64
# languages                      int64
# main_speaker                  object
# name                          object
# num_speaker                    int64
# published_date                 int64
# ratings                       object
# related_talks                 object
# speaker_occupation            object
# tags                          object
# title                         object
# url                           object
# views                          int64
# comments_per_view            float64
# views_per_comment            float64
# film_datetime         datetime64[ns]
# rating_list                   object
# dtype: object

# %%
#apply and map f() are closely related.if i want to apply x function to whole col i use apply.
#i use map to do dictionary mapping. {"a":1,"b":2} etc. For creating new col with old cols data.
#tip:pay attention to dtypes,use apply even its considered slow (from time to time)

# %% [markdown]
# <a id="7"></a>
# ## Total Number of Ratings Received by Each Talk

# %%
ted.head()
# Out:
#    comments                        ...                                                                rating_list
# 0      4553                        ...                          [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1       265                        ...                          [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2       124                        ...                          [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3       200                        ...                          [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4       593                        ...                          [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
#
# [5 rows x 21 columns]

# %%
#function time (step by step)
def get_num_ratings(list_of_dicts):
    return list_of_dicts[0]

# %%
get_num_ratings(ted.rating_list[0])
# Out:
# {'id': 7, 'name': 'Funny', 'count': 19645}

# %%
def get_num_ratings2(list_of_dicts):
    return list_of_dicts[0]["count"]

# %%
get_num_ratings2(ted.rating_list[0])
# Out:
# 19645

# %%
def get_num_ratings3(list_of_dicts):
    num=0
    for d in list_of_dicts:
        num=num+d["count"]
    return num

# %%
get_num_ratings3(ted.rating_list[0])
# Out:
# 93850

# %%
ted.rating_list.apply(get_num_ratings3)
# Out:
# 0       93850
# 1        2936
# 2        2824
# 3        3728
# 4       25620
# 5       15356
# 6        5998
# 7        1024
# 8        3946
# 9        8327
# 10       1780
# 11        592
# 12        886
# 13       8317
# 14        781
# 15       6239
# 16       4679
# 17       1788
# 18       1931
# 19       1571
# 20       1177
# 21       5164
# 22        784
# 23      10780
# 24       2570
# 25       3544
# 26       4594
# 27       2036
# 28      10678
# 29      19834
#         ...
# 2520      280
# 2521      320
# 2522      279
# 2523      367
# 2524      166
# 2525      413
# 2526      450
# 2527      320
# 2528       68
# 2529      583
# 2530      468
# 2531      159
# 2532      981
# 2533      183
# 2534      221
# 2535      431
# 2536      259
# 2537     2009
# 2538      231
# 2539      256
# 2540      383
# 2541      378
# 2542      181
# 2543      225
# 2544      143
# 2545      192
# 2546      151
# 2547      136
# 2548      583
# 2549      142
# Name: rating_list, Length: 2550, dtype: int64

# %%
ted["num_ratings"]=ted.rating_list.apply(get_num_ratings3)

# %%
ted.num_ratings.describe()
# Out:
# count     2550.000000
# mean      2436.408235
# std       4226.795631
# min         68.000000
# 25%        870.750000
# 50%       1452.500000
# 75%       2506.750000
# max      93850.000000
# Name: num_ratings, dtype: float64

# %%
#alternative methods.
#for first item in rating_list these are the results.
pd.DataFrame(ted.rating_list[0])
# Out:
#     count  id          name
# 0   19645   7         Funny
# 1    4573   1     Beautiful
# 2    6073   9     Ingenious
# 3    3253   3    Courageous
# 4     387  11    Longwinded
# 5     242   2     Confusing
# 6    7346   8   Informative
# 7   10581  22   Fascinating
# 8     300  21  Unconvincing
# 9   10704  24    Persuasive
# 10   4439  23  Jaw-dropping
# 11   1174  25            OK
# 12    209  26     Obnoxious
# 13  24924  10     Inspiring

# %%
#sort it out
pd.DataFrame(ted.rating_list[0]).sort_values("count",ascending=False)
#for first talk in list top count is inspiring with 24k, id is emotion_id(10 is for inspiring)
#for first talk in the list there are total of 93k tags.If u put 1 inside of sqr brackets u see the dif results for 2nd data
# Out:
#     count  id          name
# 13  24924  10     Inspiring
# 0   19645   7         Funny
# 9   10704  24    Persuasive
# 7   10581  22   Fascinating
# 6    7346   8   Informative
# 2    6073   9     Ingenious
# 1    4573   1     Beautiful
# 10   4439  23  Jaw-dropping
# 3    3253   3    Courageous
# 11   1174  25            OK
# 4     387  11    Longwinded
# 8     300  21  Unconvincing
# 5     242   2     Confusing
# 12    209  26     Obnoxious

# %%
#to get total count
#u cant use use .count.sum() bcs colname conflicts with attribute.thats the result.U can change it to 1-2 etc to see others.
pd.DataFrame(ted.rating_list[0])["count"].sum()
# Out:
# 93850

# %% [markdown]
# <a id="8"></a>
# ## Which Occupations Have the Funniest TED Talks on AVG

# %%
#step by step process.lets dive in.
#step1:count the no of funny ratings

# %%
ted.rating_list.head()
# Out:
# 0    [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1    [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2    [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3    [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4    [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# Name: rating_list, dtype: object

# %%
#we want to check if all talks have funny tags in them
ted.ratings.str.contains("Funny").value_counts()
#its always there.
# Out:
# True    2550
# Name: ratings, dtype: int64

# %%
#function time again.
def get_funny_ratings(list_of_dicts):
    for d in list_of_dicts:
        if d["name"]=="Funny":
            return d["count"]

# %%
ted["funny_ratings"]=ted.rating_list.apply(get_funny_ratings)

# %%
#now we have every talks "funny" tag count in id order.
ted.funny_ratings.head()
# Out:
# 0    19645
# 1      544
# 2      964
# 3       59
# 4     1390
# Name: funny_ratings, dtype: int64

# %%
#step2:lets get a percentage approach.
#lets get percentage based approach to see how much of our "tags" are funny in that specific talk
ted["funny_rate"]=ted.funny_ratings/ted.num_ratings

# %%
#lets do a fact check.to see our data is correct-here is the whole data.
#what should i check from here to see if our approach is correct.speakers.occupation.comedian=higher,scientist=lower...
ted.sort_values("funny_rate",ascending=False).head()
# Out:
#       comments    ...     funny_rate
# 685        233    ...       0.702076
# 1398       200    ...       0.669927
# 747        287    ...       0.630677
# 173         71    ...       0.629662
# 2114       150    ...       0.625182
#
# [5 rows x 24 columns]

# %%
#reasonable.these dudes are funniest by their sheer funny_rate sorting results.
ted.sort_values("funny_rate",ascending=False).speaker_occupation.head()
# Out:
# 685     Actor, comedian, playwright
# 1398                       Comedian
# 747                        Comedian
# 173                        Investor
# 2114            Comedian and writer
# Name: speaker_occupation, dtype: object

# %%
#least funny dudes.
ted.sort_values("funny_rate",ascending=True).speaker_occupation.head()
# Out:
# 2549     Game designer
# 1612         Biologist
# 612           Sculptor
# 998     Penguin expert
# 593           Engineer
# Name: speaker_occupation, dtype: object

# %%
#step3:Analyze the funny rate by occupation

# %%
#x by y or x for each y wordsets used with groupby most of the time.
#for each occupation analyze funny rate.Is this dude's occupation funny or Is it about that dude specificly?

# %%
ted.groupby("speaker_occupation").funny_rate.mean().sort_values(ascending=False)
#a lot of these occupations have very small sample size 1 most of the time.
# Out:
# speaker_occupation
# Comedian and writer                     0.602085
# Jugglers                                0.566828
# Actor, comedian, playwright             0.558107
# Actor, writer                           0.515152
# Comedian                                0.512457
# Satirist                                0.512383
# Cartoon editor                          0.511628
# Comedian, voice artist                  0.503542
# Social energy entrepreneur              0.502117
# Science humorist                        0.468405
# Comedian + Designer                     0.463068
# African grey parrot                     0.441525
# Pranksters                              0.437240
# Marketing expert                        0.434353
# Philosopher-comic                       0.415871
# Expert                                  0.415295
# First aid instructor                    0.413043
# Entrepreneur, Lego enthusiast           0.409814
# YouTube trends manager                  0.404886
# Cartoonist                              0.369335
# Ornithologist                           0.361057
# Amateur musicians                       0.356574
# Humorist, web artist                    0.354504
# Information security manager            0.352557
# Neuroscientist, stand-up comic          0.352342
# Author, satirist                        0.350423
# Children's book author                  0.344057
# Musician and graphic designer           0.328194
# Comedian, filmmaker                     0.325000
# Close-up card magician                  0.322728
#                                           ...
# Spinal cord researcher                  0.000000
# Building activist                       0.000000
# Immigration scholar                     0.000000
# Labor-rights activist                   0.000000
# Writer, peace advocate                  0.000000
# Journalist, news anchor                 0.000000
# Kenyan MP                               0.000000
# Historian, philosopher                  0.000000
# Mental health advocate                  0.000000
# Ethnic conflicts scholar                0.000000
# Artist and filmmaker                    0.000000
# Environmental engineer                  0.000000
# Violence and abuse prevention expert    0.000000
# Foreign Minister of Norway              0.000000
# Forensic anthropologist                 0.000000
# Penguin expert                          0.000000
# Digital archaeologist                   0.000000
# Mental health care advocate             0.000000
# Planetary explorer                      0.000000
# Computational geneticist                0.000000
# Medicine law expert                     0.000000
# Data Commons Advocate                   0.000000
# Executive chair, Ford Motor Co.         0.000000
# Author, producer                        0.000000
# Craft artist, product designer          0.000000
# Aid worker                              0.000000
# Author, thinker                         0.000000
# HIV/AIDS fighter                        0.000000
# Political scientist and journalist      0.000000
#  Chairman of the Cordoba Initiative     0.000000
# Name: funny_rate, Length: 1458, dtype: float64

# %%
#as u can see.why its 2544 rather than 2550.bcs there are 6 null cases.
ted.speaker_occupation.describe()
# Out:
# count       2544
# unique      1458
# top       Writer
# freq          45
# Name: speaker_occupation, dtype: object

# %%
#another approach-more cleaner one.the most highest ones have only 1 or 2 samples.
ted.groupby("speaker_occupation").funny_rate.agg(["mean","count"]).sort_values(by="mean",ascending=False)
# Out:
#                                           mean  count
# speaker_occupation
# Comedian and writer                   0.602085      2
# Jugglers                              0.566828      1
# Actor, comedian, playwright           0.558107      2
# Actor, writer                         0.515152      1
# Comedian                              0.512457      6
# Satirist                              0.512383      1
# Cartoon editor                        0.511628      1
# Comedian, voice artist                0.503542      1
# Social energy entrepreneur            0.502117      1
# Science humorist                      0.468405      1
# Comedian + Designer                   0.463068      1
# African grey parrot                   0.441525      1
# Pranksters                            0.437240      1
# Marketing expert                      0.434353      1
# Philosopher-comic                     0.415871      1
# Expert                                0.415295      2
# First aid instructor                  0.413043      1
# Entrepreneur, Lego enthusiast         0.409814      1
# YouTube trends manager                0.404886      1
# Cartoonist                            0.369335      1
# Ornithologist                         0.361057      2
# Amateur musicians                     0.356574      1
# Humorist, web artist                  0.354504      3
# Information security manager          0.352557      1
# Neuroscientist, stand-up comic        0.352342      1
# Author, satirist                      0.350423      1
# Children's book author                0.344057      1
# Musician and graphic designer         0.328194      1
# Comedian, filmmaker                   0.325000      1
# Close-up card magician                0.322728      1
# ...                                        ...    ...
# Forensic anthropologist               0.000000      1
# Artist and filmmaker                  0.000000      1
# Writer, peace advocate                0.000000      1
# Immigration scholar                   0.000000      1
# HIV/AIDS fighter                      0.000000      1
# Aid worker                            0.000000      1
# Historian, philosopher                0.000000      1
# Computational geneticist              0.000000      1
# Planetary explorer                    0.000000      1
# Foreign Minister of Norway            0.000000      1
# Building activist                     0.000000      1
# Violence and abuse prevention expert  0.000000      1
# Clinical professor of law             0.000000      1
# Craft artist, product designer        0.000000      1
# Data Commons Advocate                 0.000000      1
# Mental health care advocate           0.000000      1
# Digital archaeologist                 0.000000      1
# Mental health advocate                0.000000      1
# Medicine law expert                   0.000000      1
# Penguin expert                        0.000000      1
# Author, producer                      0.000000      1
# Environmental engineer                0.000000      1
# Ethnic conflicts scholar              0.000000      1
# Executive chair, Ford Motor Co.       0.000000      1
# Spinal cord researcher                0.000000      1
# Labor-rights activist                 0.000000      1
# Political scientist and journalist    0.000000      1
# Kenyan MP                             0.000000      1
# Author, thinker                       0.000000      1
#  Chairman of the Cordoba Initiative   0.000000      1
#
# [1458 rows x 2 columns]

# %%
#step4:focus on occupations that are well represented in the data.

# %%
occupation_counts=ted.speaker_occupation.value_counts()
occupation_counts
# Out:
# Writer                                       45
# Artist                                       34
# Designer                                     34
# Journalist                                   33
# Entrepreneur                                 31
# Architect                                    30
# Inventor                                     27
# Psychologist                                 26
# Photographer                                 25
# Filmmaker                                    21
# Educator                                     20
# Economist                                    20
# Neuroscientist                               20
# Author                                       20
# Roboticist                                   16
# Philosopher                                  16
# Biologist                                    15
# Physicist                                    14
# Marine biologist                             11
# Musician                                     11
# Global health expert; data visionary         10
# Technologist                                 10
# Activist                                     10
# Historian                                     9
# Singer/songwriter                             9
# Behavioral economist                          9
# Oceanographer                                 9
# Philanthropist                                9
# Graphic designer                              9
# Poet                                          9
#                                              ..
# Violence and abuse prevention expert          1
# Physician and men’s health advocate           1
# Anti-extremism activist                       1
# Nanobiotechnologist                           1
# Physician, disaster-preparedness activist     1
# Puzzlemaster                                  1
# Healthcare innovator                          1
# Transportation specialist                     1
# Environmental scientist                       1
# Aerialist                                     1
# Undercover journalist                         1
# Nose                                          1
# Cancer Researcher                             1
# Campaign leader, Global Witness               1
# Professor of international law                1
# Neurological anthropologist                   1
# Creative arts therapist                       1
# Green designer                                1
# Ecological entomologist                       1
# Sound artist, composer                        1
# Dancer and choreographer                      1
# Surgeon, inventor                             1
# Neuroscientist, stand-up comic                1
# Food urbanist                                 1
# Close-up card magician                        1
# Experimental micromechanics pioneer           1
# Foreign Minister of Norway                    1
# Entrepreneur and philanthropist               1
# Public sector researcher                      1
# Lie detector                                  1
# Name: speaker_occupation, Length: 1458, dtype: int64

# %%
#lets define a frequency for our sample.then use filters.
occupation_counts[occupation_counts>=5]
# Out:
# Writer                                        45
# Artist                                        34
# Designer                                      34
# Journalist                                    33
# Entrepreneur                                  31
# Architect                                     30
# Inventor                                      27
# Psychologist                                  26
# Photographer                                  25
# Filmmaker                                     21
# Educator                                      20
# Economist                                     20
# Neuroscientist                                20
# Author                                        20
# Roboticist                                    16
# Philosopher                                   16
# Biologist                                     15
# Physicist                                     14
# Marine biologist                              11
# Musician                                      11
# Global health expert; data visionary          10
# Technologist                                  10
# Activist                                      10
# Historian                                      9
# Singer/songwriter                              9
# Behavioral economist                           9
# Oceanographer                                  9
# Philanthropist                                 9
# Graphic designer                               9
# Poet                                           9
#                                               ..
# Writer, activist                               6
# Reporter                                       6
# Singer-songwriter                              6
# Social entrepreneur                            6
# Techno-illusionist                             6
# Comedian                                       6
# Evolutionary biologist                         6
# Climate advocate                               6
# Legal activist                                 6
# Photojournalist                                6
# Performance poet, multimedia artist            6
# Musician, activist                             5
# Investor and advocate for moral leadership     5
# Violinist                                      5
# Producer                                       5
# Paleontologist                                 5
# Game designer                                  5
# Sound consultant                               5
# Sculptor                                       5
# Researcher                                     5
# Surgeon                                        5
# Environmentalist, futurist                     5
# Tech visionary                                 5
# Social Media Theorist                          5
# Chemist                                        5
# Cartoonist                                     5
# Science writer                                 5
# Data scientist                                 5
# Chef                                           5
# Physician                                      5
# Name: speaker_occupation, Length: 68, dtype: int64

# %%
#save these top occupations.
top_occupations=occupation_counts[occupation_counts>=5].index
top_occupations
# Out:
# Index(['Writer', 'Artist', 'Designer', 'Journalist', 'Entrepreneur',
#        'Architect', 'Inventor', 'Psychologist', 'Photographer', 'Filmmaker',
#        'Educator', 'Economist', 'Neuroscientist', 'Author', 'Roboticist',
#        'Philosopher', 'Biologist', 'Physicist', 'Marine biologist', 'Musician',
#        'Global health expert; data visionary', 'Technologist', 'Activist',
#        'Historian', 'Singer/songwriter', 'Behavioral economist',
#        'Oceanographer', 'Philanthropist', 'Graphic designer', 'Poet',
#        'Astronomer', 'Futurist', 'Computer scientist', 'Engineer',
#        'Social psychologist', 'Novelist', 'Astrophysicist', 'Mathematician',
#        'Writer, activist', 'Reporter', 'Singer-songwriter',
#        'Social entrepreneur', 'Techno-illusionist', 'Comedian',
#        'Evolutionary biologist', 'Climate advocate', 'Legal activist',
#        'Photojournalist', 'Performance poet, multimedia artist',
#        'Musician, activist', 'Investor and advocate for moral leadership',
#        'Violinist', 'Producer', 'Paleontologist', 'Game designer',
#        'Sound consultant', 'Sculptor', 'Researcher', 'Surgeon',
#        'Environmentalist, futurist', 'Tech visionary', 'Social Media Theorist',
#        'Chemist', 'Cartoonist', 'Science writer', 'Data scientist', 'Chef',
#        'Physician'],
#       dtype='object')

# %%
#here is the result's type.Index.Index can be treated like a list.thats the key.
type(top_occupations)
# Out:
# pandas.core.indexes.base.Index

# %%
#filter time using isin() returns true for the ones thats inside of that col and only true results ll be shown.
ted[ted.speaker_occupation.isin(top_occupations)]
#isin is sth like multiple OR's.lets save it.
# Out:
#       comments    ...     funny_rate
# 1          265    ...       0.185286
# 4          593    ...       0.054254
# 7           46    ...       0.008789
# 11          55    ...       0.008446
# 14          99    ...       0.017926
# 15         325    ...       0.030454
# 26         507    ...       0.027645
# 27          95    ...       0.238212
# 28         355    ...       0.156209
# 30         991    ...       0.102108
# 34          58    ...       0.006623
# 39         112    ...       0.026832
# 40          58    ...       0.008403
# 46          52    ...       0.005889
# 48          95    ...       0.358248
# 50          85    ...       0.002988
# 53          59    ...       0.006954
# 54         203    ...       0.015894
# 56          47    ...       0.021786
# 60          28    ...       0.005254
# 62         226    ...       0.055201
# 63          97    ...       0.009306
# 64          89    ...       0.025186
# 65         107    ...       0.001267
# 70         130    ...       0.022189
# 71          49    ...       0.025473
# 72          86    ...       0.233883
# 74          50    ...       0.012590
# 78          84    ...       0.207957
# 79         131    ...       0.011270
# ...        ...    ...            ...
# 2431        27    ...       0.005828
# 2432        30    ...       0.011166
# 2434        32    ...       0.007864
# 2436        53    ...       0.003053
# 2442        92    ...       0.009025
# 2444        35    ...       0.007037
# 2449        15    ...       0.024554
# 2456       183    ...       0.013482
# 2464        18    ...       0.000000
# 2465        10    ...       0.014970
# 2467        35    ...       0.005097
# 2470        28    ...       0.005563
# 2487        29    ...       0.027620
# 2493        59    ...       0.011710
# 2498        40    ...       0.082192
# 2499        46    ...       0.047120
# 2502        20    ...       0.016432
# 2506        36    ...       0.020808
# 2523        20    ...       0.008174
# 2530        12    ...       0.068376
# 2533         9    ...       0.010929
# 2534         2    ...       0.018100
# 2535         8    ...       0.044084
# 2537        39    ...       0.001493
# 2538         7    ...       0.021645
# 2539        10    ...       0.007812
# 2541        12    ...       0.103175
# 2542         3    ...       0.033149
# 2545        17    ...       0.005208
# 2549         8    ...       0.000000
#
# [786 rows x 24 columns]

# %%
ted_top_occupations=ted[ted.speaker_occupation.isin(top_occupations)]

# %%
#from 2544 speaker occupations,this is what we have left.786.
ted_top_occupations.shape
# Out:
# (786, 24)

# %%
ted_top_occupations.groupby("speaker_occupation").funny_rate.mean().sort_values(ascending=False)
#weaknesses of these approach=5 is small sample size.
#also that performance poet dude that has done at least 5 ted talks however its all the same dude so result for performance
#poets is quite high.
#data is problematic in a sense that most of the speakers have more than 1 occupation..
# Out:
# speaker_occupation
# Comedian                                      0.512457
# Performance poet, multimedia artist           0.306468
# Singer/songwriter                             0.252205
# Producer                                      0.202531
# Data scientist                                0.184076
# Cartoonist                                    0.162120
# Techno-illusionist                            0.152171
# Graphic designer                              0.135718
# Poet                                          0.107398
# Global health expert; data visionary          0.090306
# Artist                                        0.078939
# Author                                        0.075508
# Entrepreneur                                  0.073295
# Novelist                                      0.070876
# Evolutionary biologist                        0.069157
# Reporter                                      0.066250
# Game designer                                 0.062317
# Writer                                        0.060745
# Designer                                      0.059287
# Science writer                                0.055993
# Chef                                          0.054207
# Technologist                                  0.050965
# Behavioral economist                          0.050460
# Futurist                                      0.050460
# Filmmaker                                     0.048603
# Physicist                                     0.046302
# Musician                                      0.045336
# Psychologist                                  0.044984
# Astronomer                                    0.044581
# Roboticist                                    0.042777
#                                                 ...
# Engineer                                      0.031711
# Architect                                     0.030579
# Computer scientist                            0.029070
# Journalist                                    0.027997
# Writer, activist                              0.026665
# Economist                                     0.025488
# Musician, activist                            0.023395
# Historian                                     0.023215
# Legal activist                                0.022303
# Sound consultant                              0.022011
# Inventor                                      0.021801
# Social entrepreneur                           0.017921
# Social Media Theorist                         0.017450
# Sculptor                                      0.016960
# Tech visionary                                0.016654
# Social psychologist                           0.015887
# Paleontologist                                0.015780
# Oceanographer                                 0.014596
# Astrophysicist                                0.013147
# Activist                                      0.012539
# Philanthropist                                0.012522
# Chemist                                       0.010970
# Singer-songwriter                             0.010597
# Violinist                                     0.009534
# Environmentalist, futurist                    0.007317
# Photographer                                  0.007152
# Investor and advocate for moral leadership    0.005198
# Photojournalist                               0.004908
# Physician                                     0.004515
# Surgeon                                       0.002465
# Name: funny_rate, Length: 68, dtype: float64
